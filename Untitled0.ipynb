# %%
l1=[2,3,4]
l2=[45,6,9]
print(l1+l2)
# Out:
# [2, 3, 4, 45, 6, 9]

# %%
l3=[6,3,2]
l4=3
print(l3*l4)
# Out:
# [6, 3, 2, 6, 3, 2, 6, 3, 2]

# %%
import numpy as np
n1=np.array([2,3,4])
n2=np.array([45,6,9])
print(n1+n2)
# Out:
# [47  9 13]

# %%
n3=np.array([6,3,2])
n4=3
print(n3*n4)
# Out:
# [18  9  6]

# %%
n4=np.array([23,"sang",4])
print(n4)
# Out:
# ['23' 'sang' '4']
